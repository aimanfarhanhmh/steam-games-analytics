# %%
import requests
import pandas as pd

data = requests.get("https://steamspy.com/api.php?request=all")

print(type(data.json()))

df = pd.DataFrame(data.json()).T

print(data.json())
# Out:
# <class 'dict'>
# {'570': {'appid': 570, 'name': 'Dota 2', 'developer': 'Valve', 'publisher': 'Valve', 'score_rank': '', 'positive': 1825725, 'negative': 403830, 'userscore': 0, 'owners': '200,000,000 .. 500,000,000', 'average_forever': 42129, 'average_2weeks': 1885, 'median_forever': 1076, 'median_2weeks': 1123, 'price': '0', 'initialprice': '0', 'discount': '0', 'ccu': 717237}, '730': {'appid': 730, 'name': 'Counter-Strike: Global Offensive', 'developer': 'Valve', 'publisher': 'Valve', 'score_rank': '', 'positive': 7007401, 'negative': 1024982, 'userscore': 0, 'owners': '100,000,000 .. 200,000,000', 'average_forever': 29960, 'average_2weeks': 797, 'median_forever': 5345, 'median_2weeks': 334, 'price': '0', 'initialprice': '0', 'discount': '0', 'ccu': 1114239}, '578080': {'appid': 578080, 'name': 'PUBG: BATTLEGROUNDS', 'developer': 'KRAFTON, Inc.', 'publisher': 'KRAFTON, Inc.', 'score_rank': '', 'positive': 1372365, 'negative': 979113, 'userscore': 0, 'owners': '50,000,000 .. 100,000,000', 'average_forever': 22904, 'average_2weeks': 814, 'median_forever': 6434, 'median_2weeks': 242, 'price': '0', 'initialprice': '0', 'discount': '0', 'ccu': 358525}, '1623730': {'appid': 1623730, 'name': 'Palworld', 'developer': 'Pocketpair', 'publisher': 'Pocketpair', 'score_rank': '', 'positive': 277970, 'negative': 18267, 'userscore': 0, 'owners': '50,000,000 .. 100,000,000', 'average_forever': 2823, 'average_2weeks': 846, 'median_forever': 1824, 'median_2weeks': 271, 'price': '2999', 'initialprice': '2999', 'discount': '0', 'ccu': 35377}, '1063730': {'appid': 1063730, 'name': 'New World', 'developer': 'Amazon Games', 'publisher': 'Amazon Games', 'score_rank': '', 'positive': 192931, 'negative': 81336, 'userscore': 0, 'owners': '50,000,000 .. 100,000,000', 'average_forever': 7726, 'average_2weeks': 125, 'median_forever': 3273, 'median_2weeks': 188, 'price': '3999', 'initialprice': '3999', 'discount': '0', 'ccu': 9067}, '553850': {'appid': 553850, 'name': 'HELLDIVERS 2', 'developer': 'Arrowhead Game Studios', 'publisher': 'PlayStation PC LLC', 'score_rank': '', 'positive': 331052, 'negative': 301208, 'userscore': 0, 'owners': '50,000,000 .. 100,000,000', 'average_forever': 2541, 'average_2weeks': 540, 'median_forever': 1953, 'median_2weeks': 315, 'price': '3999', 'initialprice': '3999', 'discount': '0', 'ccu': 107655}, '440': {'appid': 440, 'name': 'Team Fortress 2', 'developer': 'Valve', 'publisher': 'Valve', 'score_rank': '', 'positive': 978130, 'negative': 64600, 'userscore': 0, 'owners': '50,000,000 .. 100,000,000', 'average_forever': 11020, 'average_2weeks': 1474, 'median_forever': 384, 'median_2weeks': 263, 'price': '0', 'initialprice': '0', 'discount': '0', 'ccu': 76039}, '1172470': {'appid': 1172470, 'name': 'Apex Legends', 'developer': 'Respawn', 'publisher': 'Electronic Arts', 'score_rank': '', 'positive': 640796, 'negative': 180120, 'userscore': 0, 'owners': '50,000,000 .. 100,000,000', 'average_forever': 8118, 'average_2weeks': 647, 'median_forever': 801, 'median_2weeks': 340, 'price': '0', 'initialprice': '0', 'discount': '0', 'ccu': 203655}, '271590': {'appid': 271590, 'name': 'Grand Theft Auto V', 'developer': 'Rockstar North', 'publisher': 'Rockstar Games', 'score_rank': '', 'positive': 1553489, 'negative': 236578, 'userscore': 0, 'owners': '50,000,000 .. 100,000,000', 'average_forever': 13410, 'average_2weeks': 631, 'median_forever': 5970, 'median_2weeks': 163, 'price': '2998', 'initialprice': '2998', 'discount': '0', 'ccu': 125855}, '1938090': {'appid': 1938090, 'name': 'Call of Duty: Modern Warfare II', 'developer': 'Sledgehammer Games, Treyarch, Infinity Ward, Beenox, Raven Software, High Moon Studios, Demonware', 'publisher': 'Activision', 'score_rank': '', 'positive': 328945, 'negative': 237505, 'userscore': 0, 'owners': '50,000,000 .. 100,000,000', 'average_forever': 4191, 'average_2weeks': 714, 'median_forever': 541, 'median_2weeks': 336, 'price': '6999', 'initialprice': '6999', 'discount': '0', 'ccu': 117163}, '550': {'appid': 550, 'n ...

# %%
df.head()
# Out:
#            appid                              name      developer  \
# 570          570                            Dota 2          Valve
# 730          730  Counter-Strike: Global Offensive          Valve
# 578080    578080               PUBG: BATTLEGROUNDS  KRAFTON, Inc.
# 1623730  1623730                          Palworld     Pocketpair
# 1063730  1063730                         New World   Amazon Games
#
#              publisher score_rank positive negative userscore  \
# 570              Valve             1825725   403830         0
# 730              Valve             7007401  1024982         0
# 578080   KRAFTON, Inc.             1372365   979113         0
# 1623730     Pocketpair              277970    18267         0
# 1063730   Amazon Games              192931    81336         0
#
#                              owners average_forever average_2weeks  \
# 570      200,000,000 .. 500,000,000           42129           1885
# 730      100,000,000 .. 200,000,000           29960            797
# 578080    50,000,000 .. 100,000,000           22904            814
# 1623730   50,000,000 .. 100,000,000            2823            846
# 1063730   50,000,000 .. 100,000,000            7726            125
#
#         median_forever median_2weeks price initialprice discount      ccu
# 570               1076          1123     0            0        0   717237
# 730               5345           334     0            0        0  1114239
# 578080            6434           242     0            0        0   358525
# 1623730           1824           271  2999         2999        0    35377
# 1063730           3273           188  3999         3999        0     9067

# %%
sorted_by_pos_review = df.sort_values(by=['positive'], ascending=False)
sorted_by_pos_review.head()
# Out:
#          appid                              name       developer  \
# 730        730  Counter-Strike: Global Offensive           Valve
# 570        570                            Dota 2           Valve
# 271590  271590                Grand Theft Auto V  Rockstar North
# 578080  578080               PUBG: BATTLEGROUNDS   KRAFTON, Inc.
# 105600  105600                          Terraria        Re-Logic
#
#              publisher score_rank positive negative userscore  \
# 730              Valve             7007401  1024982         0
# 570              Valve             1825725   403830         0
# 271590  Rockstar Games             1553489   236578         0
# 578080   KRAFTON, Inc.             1372365   979113         0
# 105600        Re-Logic             1250509    30375         0
#
#                             owners average_forever average_2weeks  \
# 730     100,000,000 .. 200,000,000           29960            797
# 570     200,000,000 .. 500,000,000           42129           1885
# 271590   50,000,000 .. 100,000,000           13410            631
# 578080   50,000,000 .. 100,000,000           22904            814
# 105600    20,000,000 .. 50,000,000            7395            843
#
#        median_forever median_2weeks price initialprice discount      ccu
# 730              5345           334     0            0        0  1114239
# 570              1076          1123     0            0        0   717237
# 271590           5970           163  2998         2998        0   125855
# 578080           6434           242     0            0        0   358525
# 105600           1627           398   999          999        0    34734

# %%
df_not_free = df.drop(df[df.price == '0'].index).sort_values(by=['positive'], ascending=False)
df_not_free.head()
# Out:
#          appid                            name          developer  \
# 271590  271590              Grand Theft Auto V     Rockstar North
# 105600  105600                        Terraria           Re-Logic
# 359550  359550  Tom Clancy's Rainbow Six Siege   Ubisoft Montreal
# 4000      4000                     Garry's Mod  Facepunch Studios
# 252490  252490                            Rust  Facepunch Studios
#
#                 publisher score_rank positive negative userscore  \
# 271590     Rockstar Games             1553489   236578         0
# 105600           Re-Logic             1250509    30375         0
# 359550            Ubisoft             1090983   188882         0
# 4000                Valve             1029522    34751         0
# 252490  Facepunch Studios              918675   136201         0
#
#                            owners average_forever average_2weeks  \
# 271590  50,000,000 .. 100,000,000           13410            631
# 105600   20,000,000 .. 50,000,000            7395            843
# 359550   20,000,000 .. 50,000,000           14245            639
# 4000     20,000,000 .. 50,000,000            9557            160
# 252490  50,000,000 .. 100,000,000           20274            690
#
#        median_forever median_2weeks price initialprice discount     ccu
# 271590           5970           163  2998         2998        0  125855
# 105600           1627           398   999          999        0   34734
# 359550           2716           160  1999         1999        0   92615
# 4000             1327            51   999          999        0   35375
# 252490           2884           398  3999         3999        0  153662
