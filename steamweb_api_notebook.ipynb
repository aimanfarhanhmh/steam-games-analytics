# %% [markdown]
# # Extracting Steam Game Data Using Steam API

# %% [markdown]
# ## Requirements

# %% [markdown]
# Run cell below to install required packages

# %%
### Uncomment to install pakages
# !pip install numpy
# !pip install pandas 
# !pip install requests
# Out:
# Requirement already satisfied: numpy in c:\users\ahish\anaconda3\lib\site-packages (1.24.3)
# Requirement already satisfied: pandas in c:\users\ahish\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ahish\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ahish\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\ahish\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\ahish\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: requests in c:\users\ahish\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ahish\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ahish\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ahish\anaconda3\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ahish\anaconda3\lib\site-packages (from requests) (2023.7.22)

# %% [markdown]
# ## Code

# %%
import json
import requests
import pandas as pd
import numpy as np
from pathlib import Path

APP_ID = 413150
URL = f"https://store.steampowered.com/api/appdetails?appids={APP_ID}&l=english"

response = requests.get(url=URL)
response.status_code

data = json.loads(response.text)[f"{APP_ID}"]['data']

# %%
## some settings for pandas

# display all columns 
pd.set_option('display.max_columns', None)

#  
pd.options.mode.chained_assignment = None  # default='warn'

# %%
df = pd.json_normalize(data)
df.head()
# Out:
#    type            name  steam_appid  required_age  is_free  \
# 0  game  Stardew Valley       413150             0    False
#
#   controller_support       dlc  \
# 0               full  [440820]
#
#                                 detailed_description  \
# 0  Stardew Valley is an open-ended country-life R...
#
#                                       about_the_game  \
# 0  Stardew Valley is an open-ended country-life R...
#
#                                    short_description  \
# 0  You've inherited your grandfather's old farm p...
#
#                                  supported_languages  \
# 0  English, German, Spanish - Spain, Japanese, Po...
#
#                                              reviews  \
# 0  “Far more than just a farming game, this one-m...
#
#                                         header_image  \
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                        capsule_image  \
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                      capsule_imagev5  \
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                         website      developers      publishers packages  \
# 0  http://www.stardewvalley.net  [ConcernedApe]  [ConcernedApe]  [82712]
#
#                                       package_groups  \
# 0  [{'name': 'default', 'title': 'Buy Stardew Val...
#
#                                           categories  \
# 0  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                               genres  \
# 0  [{'id': '23', 'description': 'Indie'}, {'id': ...
#
#                                          screenshots  \
# 0  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
#
#                                               movies  \
# 0  [{'id': 256660296, 'name': 'Stardew Valley Tra...
#
#                                           background  \
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                       background_raw  \
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                              pc_requirements.minimum  \
# 0  <strong>Minimum:</strong><br><ul class="bb_ul"...
#
#                             mac_requirements.minimum  \
# 0  <strong>Minimum:</strong><br><ul class="bb_ul"...
#
#                           linux_requirements.minimum price_overview.currency  \
# 0  <strong>Minimum:</strong><br><ul class="bb_ul"...                     MYR
#
#    price_overview.initial  price_overview.final  \
# 0                    3100                  3100
#
#    price_overview.discount_percent price_overview.initial_formatted  \
# 0                                0
#
#   price_overview.final_formatted  platforms.windows  platforms.mac  \
# 0                        RM31.00               True           True
#
#    platforms.linux  metacritic.score  \
# 0             True                89
#
#                                       metacritic.url  recommendations.total  \
# 0  https://www.metacritic.com/game/pc/stardew-val...                 595752
#
#    achievements.total                           achievements.highlighted  \
# 0                  49  [{'name': 'Greenhorn', 'path': 'https://cdn.ak...
#
#    release_date.coming_soon release_date.date support_info.url  \
# 0                     False      26 Feb, 2016
#
#           support_info.email content_descriptors.ids  \
# 0  support@stardewvalley.net                      []
#
#   content_descriptors.notes ratings.esrb.rating  \
# 0                      None                 e10
#
#                             ratings.esrb.descriptors  \
# 0  Fantasy Violence\r\nMild Blood\r\nMild Languag...
#
#   ratings.esrb.display_online_notice ratings.pegi.rating  \
# 0                               true                  12
#
#   ratings.pegi.descriptors ratings.usk.rating ratings.oflc.rating  \
# 0                 Violence                  6                  pg
#
#   ratings.dejus.rating                          ratings.dejus.descriptors  \
# 0                   12  Violência fantasiosa\r\nViolência\r\nDrogas lí...
#
#   ratings.dejus.use_age_gate ratings.dejus.required_age
# 0                       true                         12

# %%
gamedata = pd.DataFrame()

select_columns = ['steam_appid',
                  'name', 
                  'type', 
                  'required_age',  
                  'is_free',
                  'price_overview.currency',
                  'price_overview.initial',
                  'detailed_description', 
                  'about_the_game', 
                  'short_description', 
                  'platforms.windows', 
                  'platforms.mac', 
                  'platforms.linux', 
                  'recommendations.total', 
                  'metacritic.score',
                  'achievements.total',
                  'controller_support', 
                  'release_date.date']

for columns in select_columns:
    if columns not in df:
        # steamdata['metacritic.score'] = np.nan
        gamedata.loc[:,columns] = np.nan
    else:
        # steamdata['metacritic.score'] = df['metacritic.score']
        gamedata.loc[:,columns] = df[columns]

gamedata.head()
# Out:
#    steam_appid            name  type  required_age  is_free  \
# 0       413150  Stardew Valley  game             0    False
#
#   price_overview.currency  price_overview.initial  \
# 0                     MYR                    3100
#
#                                 detailed_description  \
# 0  Stardew Valley is an open-ended country-life R...
#
#                                       about_the_game  \
# 0  Stardew Valley is an open-ended country-life R...
#
#                                    short_description  platforms.windows  \
# 0  You've inherited your grandfather's old farm p...               True
#
#    platforms.mac  platforms.linux  recommendations.total  metacritic.score  \
# 0           True             True                 595752                89
#
#    achievements.total controller_support release_date.date
# 0                  49               full      26 Feb, 2016

# %%
select_columns = ['steam_appid', 'name', 'type', 'required_age',  'is_free', 'detailed_description', 'about_the_game', 'short_description', 'platforms.windows', 'platforms.mac', 'platforms.linux', 'recommendations.total', 'achievements.total', 'release_date.date']
steamdata = df[select_columns]

steamdata.head()
# Out:
#    steam_appid            name  type  required_age  is_free  \
# 0       413150  Stardew Valley  game             0    False
#
#                                 detailed_description  \
# 0  Stardew Valley is an open-ended country-life R...
#
#                                       about_the_game  \
# 0  Stardew Valley is an open-ended country-life R...
#
#                                    short_description  platforms.windows  \
# 0  You've inherited your grandfather's old farm p...               True
#
#    platforms.mac  platforms.linux  recommendations.total  achievements.total  \
# 0           True             True                 595752                  49
#
#   release_date.date
# 0      26 Feb, 2016

# %%
var_columns = ['metacritic.score', 'controller_support', 'price_overview.currency', 'price_overview.initial']

for columns in var_columns:
    if columns not in df:
        # steamdata['metacritic.score'] = np.nan
        steamdata.loc[:,columns] = np.nan
    else:
        # steamdata['metacritic.score'] = df['metacritic.score']
        steamdata.loc[:,columns] = df[columns]
steamdata.head()
# Out:
#    steam_appid            name  type  required_age  is_free  \
# 0       413150  Stardew Valley  game             0    False
#
#                                 detailed_description  \
# 0  Stardew Valley is an open-ended country-life R...
#
#                                       about_the_game  \
# 0  Stardew Valley is an open-ended country-life R...
#
#                                    short_description  platforms.windows  \
# 0  You've inherited your grandfather's old farm p...               True
#
#    platforms.mac  platforms.linux  recommendations.total  achievements.total  \
# 0           True             True                 595752                  49
#
#   release_date.date  metacritic.score controller_support  \
# 0      26 Feb, 2016                89               full
#
#   price_overview.currency  price_overview.initial
# 0                     MYR                    3100

# %%
if Path('./gamedata.csv').is_file():
    steamdata.to_csv('gamedata.csv', mode='a', index=False, header=False)
else:
    steamdata.to_csv('gamedata.csv', mode='a', index=False, header=True)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[12], line 2
#       1 if Path('./gamedata.csv').is_file():
# ----> 2     steamdata.to_csv('gamedata.csv', mode='a', index=False, header=False)
#       3 else:
#       4     steamdata.to_csv('gamedata.csv', mode='a', index=False, header=True)
#
# File c:\Users\ahish\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\ahish\anaconda3\Lib\site-packages\pandas\core\generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
#    3712     frame=df,
#    3713     header=header,
#    (...)
#    3717     decimal=decimal,
#    3718 )
# -> 3720 return DataFrameRenderer(formatter).to_csv(
#    3721     path_or_buf,
#    3722     lineterminator=lineterminator,
#    3723     sep=sep,
#    3724     encoding=encoding,
#    3725     errors=errors,
#    3726     compression=compression,
#    3727     quoting=quoting,
#    3728     columns=columns,
#    3729     index_label=index_label,
#    3730     mode=mode,
#    3731     chunksize=chunksize,
#    3732     quotechar=quotechar,
#    3733     date_format=date_format,
#    3734     doublequote=doublequote,
#    3735     escapechar=escapechar,
#    3736     storage_options=storage_options,
#    3737 )
#
# File c:\Users\ahish\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\ahish\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1189, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1168     created_buffer = False
#    1170 csv_formatter = CSVFormatter(
#    1171     path_or_buf=path_or_buf,
#    1172     lineterminator=lineterminator,
#    (...)
#    1187     formatter=self.fmt,
#    1188 )
# -> 1189 csv_formatter.save()
#    1191 if created_buffer:
#    1192     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\ahish\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.lineterminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File c:\Users\ahish\anaconda3\Lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'gamedata.csv'

# %%
# PermissionError
